# %% [markdown]
# ## Merge & Join

# %% [markdown]
# The merge() method updates the content of two DataFrame by merging them together, using the specified method(s).
#
# Use the parameters to control which values to keep and which to replace.

# %%
import pandas as pd
df1 = pd.DataFrame({'Name':['Sally','Mary','John'],
                    'Age': [50,40,30]})
df2 = pd.DataFrame({'Name':['Sally','Peter','Milky'],
                   'Age':[77,44,22]})
display(df1,df2)
newdf = df1.merge(df2, how='left')
newdf
# Out:
#     Name  Age
# 0  Sally   50
# 1   Mary   40
# 2   John   30
#     Name  Age
# 0  Sally   77
# 1  Peter   44
# 2  Milky   22
#     Name  Age
# 0  Sally   50
# 1   Mary   40
# 2   John   30

# %% [markdown]
# **Syntax**
#
# `dataframe.merge(right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)`

# %% [markdown]
# **1. `right`**

# %%
import pandas as pd

left = pd.DataFrame({
    'key': ['A', 'B', 'C'],
    'value': [1, 2, 3]
})

right = pd.DataFrame({
    'key': ['A', 'B', 'D'],
    'value': [4, 5, 6]
})

result = left.merge(right,on='key')
result
# Out:
#   key  value_x  value_y
# 0   A        1        4
# 1   B        2        5

# %% [markdown]
# **`2. how`**
#
# Type of merge to be performed (e.g., 'left', 'right', 'outer', 'inner').

# %%
result = left.merge(right, on='key', how='outer')
result
# Out:
#   key  value_x  value_y
# 0   A      1.0      4.0
# 1   B      2.0      5.0
# 2   C      3.0      NaN
# 3   D      NaN      6.0

# %%
result = left.merge(right, on='key', how='inner')
result
# Out:
#   key  value_x  value_y
# 0   A        1        4
# 1   B        2        5

# %%
result = left.merge(right, on='key', how='right')
result
# Out:
#   key  value_x  value_y
# 0   A      1.0        4
# 1   B      2.0        5
# 2   D      NaN        6

# %%
result = left.merge(right, on='key', how='left')
result
# Out:
#   key  value_x  value_y
# 0   A        1      4.0
# 1   B        2      5.0
# 2   C        3      NaN

# %% [markdown]
# **`3. on`**
#
# Column(s) to join on. Must be present in both DataFrames.

# %%
result = left.merge(right, on='key', how='inner')
result
# Out:
#   key  value_x  value_y
# 0   A        1        4
# 1   B        2        5

# %% [markdown]
# **`4. left_on`**
#
# Columns from the left DataFrame to use as keys.

# %%
left = pd.DataFrame({
    'lkey': ['A', 'B', 'C'],
    'value': [1, 2, 3]
})

result = left.merge(right, left_on='lkey', right_on='key', how='inner')
result
# Out:
#   lkey  value_x key  value_y
# 0    A        1   A        4
# 1    B        2   B        5

# %% [markdown]
# **`5. right_on`**
#
# Columns from the right DataFrame to use as keys.

# %%
result = left.merge(right, left_on='lkey', right_on='key', how='inner')
result
# Out:
#   lkey  value_x key  value_y
# 0    A        1   A        4
# 1    B        2   B        5

# %% [markdown]
# **`6. left_index`**
#
# Use the index from the left DataFrame as the join key(s).

# %%
import pandas as pd

df1 = pd.DataFrame({
    'value': [10, 20, 30]
}, index=['A', 'B', 'C'])

df2 = pd.DataFrame({
    'key': ['A', 'B', 'D'],
    'value': [1, 2, 4]
})

result = df1.merge(df2, left_index=True, right_on='key', how='inner')
print(result)
# Out:
#    value_x key  value_y
# 0       10   A        1
# 1       20   B        2

# %% [markdown]
# **`7. right_index`**
#
# If True, use the index from the right DataFrame as the join key(s).

# %%
import pandas as pd

left = pd.DataFrame({
    'key': ['A', 'B', 'C'],
    'value_left': [10, 20, 30]
},index =['2','4','6'])

right = pd.DataFrame({
    'value_right': [100, 200, 300]
}, index=['A', 'B', 'D'])

result = left.merge(right, left_on='key', right_index=True, how='inner')
result
# Out:
#   key  value_left  value_right
# 2   A          10          100
# 4   B          20          200

# %% [markdown]
# **`8. sort`**
#
# When sort=True, the resulting DataFrame will be sorted by the join keys. This parameter is useful when you want the output to be ordered based on the join keys.

# %%
import pandas as pd

left = pd.DataFrame({
    'key': ['B', 'A', 'C'],
    'value_left': [2, 1, 3]
})

right = pd.DataFrame({
    'key': ['A', 'B', 'D'],
    'value_right': [4, 5, 6]
})

result = left.merge(right, on='key', how='inner', sort=True)
result
# Out:
#   key  value_left  value_right
# 0   A           1            4
# 1   B           2            5

# %% [markdown]
# **`9. suffixes`**
#
# A tuple of strings to append to overlapping column names in the left and right DataFrames. This helps avoid column name conflict.

# %%
import pandas as pd

left = pd.DataFrame({
    'key': ['A', 'B'],
    'value': [1, 2]
})

right = pd.DataFrame({
    'key': ['A', 'B'],
    'value': [3, 4]
})

result = left.merge(right, on='key', suffixes=('_left', '_right'))
result
# Out:
#   key  value_left  value_right
# 0   A           1            3
# 1   B           2            4

# %% [markdown]
# **`10. copy`**
#
# Whether to copy data from the original DataFrames. This parameter is mainly for internal use and generally defaults to True. Setting it to False might improve performance but should be used with caution.

# %%
import pandas as pd

left = pd.DataFrame({
    'key': ['A', 'B'],
    'value': [1, 2]
})

right = pd.DataFrame({
    'key': ['A', 'B'],
    'value': [3, 4]
})

result = left.merge(right, on='key', how='inner', copy=True)
result
# Out:
#   key  value_x  value_y
# 0   A        1        3
# 1   B        2        4

# %% [markdown]
#  In this case, the copy parameter is set to True, which is the default behavior. The DataFrame is copied from the original DataFrames.

# %% [markdown]
# **`11. indicator`**
#
# Adds a column to the output DataFrame called _merge that shows which DataFrame each row comes from ('left_only', 'right_only', or 'both').

# %%
import pandas as pd

left = pd.DataFrame({
    'key': ['A', 'B', 'C'],
    'value_left': [1, 2, 3]
})

right = pd.DataFrame({
    'key': ['A', 'B', 'D'],
    'value_right': [4, 5, 6]
})

result = left.merge(right, on='key', how='outer', indicator=True)
result
# Out:
#   key  value_left  value_right      _merge
# 0   A         1.0          4.0        both
# 1   B         2.0          5.0        both
# 2   C         3.0          NaN   left_only
# 3   D         NaN          6.0  right_only

# %% [markdown]
# The _merge column shows where each row originated from: both DataFrames, only the left, or only the right DataFrame.

# %% [markdown]
# **`12. validate`**
#
# Checks if the merge is of a specific type and raises an error if it does not match the expected type. Possible values include 'one_to_one', 'one_to_many', 'many_to_one', and 'many_to_many'.

# %%
import pandas as pd

left = pd.DataFrame({
    'key': ['A', 'B'],
    'value_left': [1, 2]
})

right = pd.DataFrame({
    'key': ['A', 'B'],
    'value_right': [3, 4]
})

result = left.merge(right, on='key', how='inner', validate='many_to_many')
result
# Out:
#   key  value_left  value_right
# 0   A           1            3
# 1   B           2            4

# %% [markdown]
# The validate='one_to_one' parameter ensures that each key in the left DataFrame corresponds to at most one key in the right DataFrame and vice versa. If the data did not meet this criterion, a MergeError would be raised.

# %%
import pandas as pd
import zipfile
import os

zip_path = "C:\\Users\\winsa\\Downloads\\DataFolder.zip"
extraction_dir = 'C:\\Users\\winsa\\Desktop\\arya'
with zipfile.ZipFile(zip_path,'r')as zip_ref:
    zip_ref.extractall(extraction_dir)
print("extraction completed")
# Out:
# extraction completed

# %%
dfs = []

# %%
for file in os.listdir(extraction_dir):
    file_path=os.path.join(extraction_dir,file)

# %%
if file.endswith('.csv'):
    df.append(pd.read_csv(file_path))

# %%
concat_df = pd.concat(dfs,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 concat_df = pd.concat(df,ignore_index=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
import pandas as pd
import os

extraction_dir = 'C:\\Users\\winsa\\Desktop\\arya'  
file_path = 'C:\\Users\\winsa\\Downloads\\DataFolder.zip'

files = os.listdir(extraction_dir)
print("Files found:", files)  
for file in files:
    file_path = os.path.join(extraction_dir, file)
    
    if file.endswith('.csv'):
        try:
            dfs.append(pd.read_csv(file_path))
            print(f"Loaded {file_path}")  
        except Exception as e:
            print(f"Error reading {file_path}: {e}")  

if dfs:
    concatenated_df = pd.concat(dfs, ignore_index=True)
    print(concatenated_df.head())
else:
    print("No CSV files were found or all files could not be read.")
# Out:
# Files found: ['DataFolder', 'env', 'nailart']
# No CSV files were found or all files could not be read.

# %%
import pandas as pd
import os

folder_path = 'C:\\Users\\winsa\\Desktop\\DataFolder'

dfs = []

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        dfs.append(df)

combined_df = pd.concat(dfs, ignore_index=True)

duplicates = combined_df[combined_df.duplicated()]

print("Combined DataFrame:")
display(combined_df)
print("Duplicate Rows:")
display(duplicates)

cleaned_df = combined_df.drop_duplicates()
print('cleaned_df')
display(cleaned_df)

data = cleaned_df.set_index(['powertrain','category'])
data
# Out:
# Combined DataFrame:
#           region          category           parameter    mode  \
# 0      Australia        Historical      EV stock share    Cars
# 1      Australia        Historical      EV sales share    Cars
# 2      Australia        Historical            EV sales    Cars
# 3      Australia        Historical            EV stock    Cars
# 4      Australia        Historical            EV stock    Cars
# ...          ...               ...                 ...     ...
# 12763      World  Projection-STEPS      EV sales share    Cars
# 12764      World  Projection-STEPS      EV stock share    Cars
# 12765      World    Projection-APS  EV charging points      EV
# 12766      World    Projection-APS  EV charging points      EV
# 12767      World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain  year             unit         value
# 0                           EV  2011          percent  3.900000e-04
# 1                           EV  2011          percent  6.500000e-03
# 2                          BEV  2011         Vehicles  4.900000e+01
# 3                          BEV  2011         Vehicles  4.900000e+01
# 4                          BEV  2012         Vehicles  2.200000e+02
# ...                        ...   ...              ...           ...
# 12763                       EV  2035          percent  5.500000e+01
# 12764                       EV  2035          percent  3.100000e+01
# 12765  Publicly available fast  2035  charging points  9.400000e+06
# 12766  Publicly available slow  2035  charging points  1.500000e+07
# 12767                       EV  2035          percent  9.000000e+00
#
# [12768 rows x 8 columns]
# Duplicate Rows:
#          region    category           parameter  mode  \
# 94    Australia  Historical      EV stock share  Cars
# 95    Australia  Historical      EV sales share  Cars
# 96    Australia  Historical            EV sales  Cars
# 97    Australia  Historical            EV stock  Cars
# 98    Australia  Historical            EV stock  Cars
# ...         ...         ...                 ...   ...
# 1259  Australia  Historical            EV stock  Cars
# 1260  Australia  Historical            EV sales  Cars
# 1261  Australia  Historical      EV stock share  Cars
# 1262  Australia  Historical  EV charging points    EV
# 1263  Australia  Historical  EV charging points    EV
#
#                    powertrain  year             unit        value
# 94                         EV  2011          percent      0.00039
# 95                         EV  2011          percent      0.00650
# 96                        BEV  2011         Vehicles     49.00000
# 97                        BEV  2011         Vehicles     49.00000
# 98                        BEV  2012         Vehicles    220.00000
# ...                       ...   ...              ...          ...
# 1259                     PHEV  2022         Vehicles  21000.00000
# 1260                     PHEV  2022         Vehicles   5900.00000
# 1261                       EV  2022          percent      0.59000
# 1262  Publicly available fast  2022  charging points    470.00000
# 1263  Publicly available slow  2022  charging points   2100.00000
#
# [114 rows x 8 columns]
# cleaned_df
#           region          category           parameter    mode  \
# 0      Australia        Historical      EV stock share    Cars
# 1      Australia        Historical      EV sales share    Cars
# 2      Australia        Historical            EV sales    Cars
# 3      Australia        Historical            EV stock    Cars
# 4      Australia        Historical            EV stock    Cars
# ...          ...               ...                 ...     ...
# 12763      World  Projection-STEPS      EV sales share    Cars
# 12764      World  Projection-STEPS      EV stock share    Cars
# 12765      World    Projection-APS  EV charging points      EV
# 12766      World    Projection-APS  EV charging points      EV
# 12767      World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain  year             unit         value
# 0                           EV  2011          percent  3.900000e-04
# 1                           EV  2011          percent  6.500000e-03
# 2                          BEV  2011         Vehicles  4.900000e+01
# 3                          BEV  2011         Vehicles  4.900000e+01
# 4                          BEV  2012         Vehicles  2.200000e+02
# ...                        ...   ...              ...           ...
# 12763                       EV  2035          percent  5.500000e+01
# 12764                       EV  2035          percent  3.100000e+01
# 12765  Publicly available fast  2035  charging points  9.400000e+06
# 12766  Publicly available slow  2035  charging points  1.500000e+07
# 12767                       EV  2035          percent  9.000000e+00
#
# [12654 rows x 8 columns]
#                                              region           parameter  \
# powertrain              category
# EV                      Historical        Australia      EV stock share
#                         Historical        Australia      EV sales share
# BEV                     Historical        Australia            EV sales
#                         Historical        Australia            EV stock
#                         Historical        Australia            EV stock
# ...                                             ...                 ...
# EV                      Projection-STEPS      World      EV sales share
#                         Projection-STEPS      World      EV stock share
# Publicly available fast Projection-APS        World  EV charging points
# Publicly available slow Projection-APS        World  EV charging points
# EV                      Projection-STEPS      World      EV stock share
#
#                                             mode  year             unit  \
# powertrain              category
# EV                      Historical          Cars  2011          percent
#                         Historical          Cars  2011          percent
# BEV                     Historical          Cars  2011         Vehicles
#                         Historical          Cars  2011         Vehicles
#                         Historical          Cars  2012         Vehicles
# ...                                          ...   ...              ...
# EV                      Projection-STEPS    Cars  2035          percent
#                         Projection-STEPS    Cars  2035          percent
# Publicly available fast Projection-APS        EV  2035  charging points
# Publicly available slow Projection-APS        EV  2035  charging points
# EV                      Projection-STEPS  Trucks  2035          percent
#
#                                                  value
# powertrain              category
# EV                      Historical        3.900000e-04
#                         Historical        6.500000e-03
# BEV                     Historical        4.900000e+01
#                         Historical        4.900000e+01
#                         Historical        2.200000e+02
# ...                                                ...
# EV                      Projection-STEPS  5.500000e+01
#                         Projection-STEPS  3.100000e+01
# Publicly available fast Projection-APS    9.400000e+06
# Publicly available slow Projection-APS    1.500000e+07
# EV                      Projection-STEPS  9.000000e+00
#
# [12654 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# region       0
# parameter    0
# mode         0
# year         0
# unit         0
# value        0
# dtype: int64
